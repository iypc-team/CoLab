# %% [markdown]
# <a href="https://colab.research.google.com/github/iypc-team/CoLab/blob/master/GitHubFiles.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import absolute_import, division, print_function, unicode_literals
import os, sys, pathlib, glob
from os.path import exists, isabs, isfile, isdir
from pathlib import Path
from glob import glob, glob0, glob1, iglob

# %%
pathList = []
#  Open files from GitHub Clones an entire repo.
# !git clone -l -s git://github.com/iypc-team/Swift.git swiftDirectory
# %cd swiftDirectory
pth = Path.cwd()
pathList.append(pth)
swiftFiles = glob('**')
print('\nswiftDirectory:')
# %ls
print()

# !git clone -l -s git://github.com/iypc-team/CoLab.git colabDirectory
# %cd colabDirectory
pth =Path.cwd()
pathList.append(pth)
colabFiles = glob('**')
print('\ncolabDirectory:')
# %ls
print()

# !git clone -l -s git://github.com/iypc-team/Reinforcement-Learning.git reinforcement-learningDirectory
# %cd reinforcement-learningDirectory
pth = Path.cwd()
learningFiles = glob('**')
pathList.append(pth)
print('\nreinforcement-learningDirectory:')
# %ls
print()
# Out:
# Cloning into 'swiftDirectory'...
# warning: --local is ignored
# remote: Enumerating objects: 122, done.
# remote: Counting objects: 100% (122/122), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 122 (delta 68), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (122/122), 76.34 KiB | 1.09 MiB/s, done.
# Resolving deltas: 100% (68/68), done.
# /content/swiftDirectory
#
# swiftDirectory:
# Accessing_files.ipynb               Network_swift.ipynb
# blank_swift.ipynb                   Python_Integration_swift.ipynb
# Classifier_swift.ipynb              Python_interoperability.ipynb
# DifferentiableProtocol_swift.ipynb  Starter
# Differentiable_swift.ipynb          Swift_import_data.ipynb
# Downloads_swift.ipynb               Three_Dimensional_Plotting.ipynb
#
# Cloning into 'colabDirectory'...
# warning: --local is ignored
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (24/24), done.
# remote: Total 622 (delta 9), reused 0 (delta 0), pack-reused 598
# Receiving objects: 100% (622/622), 16.38 MiB | 35.76 MiB/s, done.
# Resolving deltas: 100% (372/372), done.
# /content/swiftDirectory/colabDirectory
#
# colabDirectory:
# 00_cartpole.ipynb
# 00_DQN.ipynb
# 00_DQN_Tutorial.ipynb
# 01_Blank_Colab.ipynb
# 01_Scrape.ipynb
# 02_TensorFlow_with_GPU.ipynb
# 0_Installs.ipynb
# Accessing_files.ipynb
# Accessing_GitHub.ipynb
# Action_Recognition_on_the_UCF101_Dataset.ipynb
# basic_classification.ipynb
# BasicComputerVision.ipynb
# blank_swift.ipynb
# cartpole.ipynb
# CartPole_Krohn.ipynb
# Classifier_swift.ipynb
# Copy_of_GDrive.ipynb
# CoreData_swift.ipynb
# Custom_differentiation.ipynb
# CVUtils_.ipynb
# DegreesToRadians_swift.ipynb
# Differentiable_swift.ipynb
# DispatchQueue_swift.ipynb
# DQN_Tutorial.ipynb
# DQN_with_GPU.ipynb
# Drive.ipynb
# Dueling_ddqn_torch.ipynb
# External_data.ipynb
# Factorial_swift.ipynb
# Firebase_swift.ipynb
# FrozenLake_2.ipynb
# Functional_API.ipynb
# Functional.ipynb
# GDrive.ipynb
# GetUserInput.ipynb
# GitHubFiles.ipynb
# iCloud.ipynb
# install_latest_swift.ipynb
# Iris_swift.ipynb
# Iterable.ipynb
# Keras_Fashion_MNIST.ipynb
# keras.ipynb
# PredictArrayValues.ipynb
# Python_Imports.ipynb
# Python_Notebook.ipynb
# Python_swift.ipynb
# Requests_Module.ipynb
# Snippets_Accessing_files.ipynb
# Sonnet_2_on_MNIST.ipynb
# _Tensor_board.ipynb
# Tensorboard.ipynb
# TensorFlow_2_0_with_GPU.ipynb
# TensorFlow_swift.ipynb
# TensorFlow_with_GPU.ipynb
# TF_Agents_Environments_Tutorial.ipynb
# TF_Agents_Policies_Tutorial.ipynb
# Three_Dimensional_Plotting.ipynb
# TorchTest.ipynb
# TPUs_in_Colab.ipynb
#
# Cloning into 'reinforcement-learningDirectory'...
# warning: --local is ignored
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 351 (delta 0), reused 0 (delta 0), pack-reused 348
# Receiving objects: 100% (351/351), 351.31 KiB | 9.49 MiB/s, done.
# Resolving deltas: 100% (200/200), done.
# /content/swiftDirectory/colabDirectory/reinforcement-learningDirectory
#
# reinforcement-learningDirectory:
# '01 DQN_Tutorial.ipynb'
# '02 TF_Agents_Environments_Tutorial.ipynb'
# '03 TF_Agents_Policies_Tutorial.ipynb'
#  04_TF_Agents_Drivers_Tutorial.ipynb
#  05_TF_Agents_Replay_Buffers_Tutorial.ipynb
#  Accessing_files.ipynb
#  blank_swift.ipynb
#  CartPole_Krohn.ipynb
#  Copy_of_FrozenLake_2.ipynb
#  DQN_Tutorial.ipynb
#  External_data_Drive,_Sheets,_and_Cloud_Storage.ipynb
#  FrozenLake_2.ipynb
#  Gym_Environment.ipynb
#  Iterable.ipynb
#  Python_Imports.ipynb
#  Python_Notebook.ipynb
#  REINFORCE_Learning_Tutorial.ipynb
#  Swift_import_data.ipynb
#  Three_Dimensional_Plotting.ipynb

# %%
fileCount = 0
for fil in colabFiles:
    fileCount += 1
    print(fileCount, fil)
# Out:
# 1 Action_Recognition_on_the_UCF101_Dataset.ipynb
# 2 00_DQN.ipynb
# 3 Snippets_Accessing_files.ipynb
# 4 00_DQN_Tutorial.ipynb
# 5 02_TensorFlow_with_GPU.ipynb
# 6 CartPole_Krohn.ipynb
# 7 Functional_API.ipynb
# 8 Copy_of_GDrive.ipynb
# 9 Python_Notebook.ipynb
# 10 DegreesToRadians_swift.ipynb
# 11 basic_classification.ipynb
# 12 cartpole.ipynb
# 13 Python_Imports.ipynb
# 14 Iterable.ipynb
# 15 FrozenLake_2.ipynb
# 16 Tensorboard.ipynb
# 17 Firebase_swift.ipynb
# 18 Accessing_GitHub.ipynb
# 19 01_Scrape.ipynb
# 20 GDrive.ipynb
# 21 Dueling_ddqn_torch.ipynb
# 22 GitHubFiles.ipynb
# 23 External_data.ipynb
# 24 DispatchQueue_swift.ipynb
# 25 _Tensor_board.ipynb
# 26 CoreData_swift.ipynb
# 27 blank_swift.ipynb
# 28 DQN_with_GPU.ipynb
# 29 TF_Agents_Environments_Tutorial.ipynb
# 30 Requests_Module.ipynb
# 31 Sonnet_2_on_MNIST.ipynb
# 32 TF_Agents_Policies_Tutorial.ipynb
# 33 DQN_Tutorial.ipynb
# 34 PredictArrayValues.ipynb
# 35 Accessing_files.ipynb
# 36 Keras_Fashion_MNIST.ipynb
# 37 TensorFlow_2_0_with_GPU.ipynb
# 38 Custom_differentiation.ipynb
# 39 keras.ipynb
# 40 Factorial_swift.ipynb
# 41 0_Installs.ipynb
# 42 iCloud.ipynb
# 43 TensorFlow_with_GPU.ipynb
# 44 Differentiable_swift.ipynb
# 45 Three_Dimensional_Plotting.ipynb
# 46 TPUs_in_Colab.ipynb
# 47 00_cartpole.ipynb
# 48 Drive.ipynb
# 49 BasicComputerVision.ipynb
# 50 Python_swift.ipynb
# 51 01_Blank_Colab.ipynb
# 52 install_latest_swift.ipynb
# 53 Classifier_swift.ipynb
# 54 GetUserInput.ipynb
# 55 TensorFlow_swift.ipynb
# 56 Functional.ipynb
# 57 TorchTest.ipynb
# 58 CVUtils_.ipynb
# 59 Iris_swift.ipynb
