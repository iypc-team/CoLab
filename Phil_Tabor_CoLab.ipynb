# %% [markdown]
# <a href="https://colab.research.google.com/github/iypc-team/CoLab/blob/master/Phil_Tabor_CoLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd
rootPath = Path.cwd()
print(rootPath)
allFiles = glob.glob('**', recursive=True)
# Out:
# /root
# /root

# %%
from __future__ import absolute_import, division, print_function
from IPython.display import clear_output
# from ColorUtil import C
print(f'')
# %pip install tensorflow
# %pip install gitpython
clear_output()

# %%
import git, glob, os, pathlib, sys
import tensorflow as tf
from os.path import *
from pathlib import Path
from git import Remote, Repo
# from ColorUtil import C

gathererList = 'https://github.com/philtabor/Gatherer'
repoList = ['https://github.com/philtabor/Youtube-Code-Repository',
            'https://github.com/philtabor/Actor-Critic-Methods-Paper-To-Code',
            'https://github.com/philtabor/Deep-Q-Learning-Paper-To-Code',
            'https://github.com/philtabor/Simple-Neural-Network',
            'https://github.com/philtabor/Reinforcement-Learning-In-Motion',
            'https://github.com/philtabor/PyBullet-Hand-Example',
            'https://github.com/philtabor/sensenet',
            'https://github.com/philtabor/OpenAI-Cartpole',
           'https://github.com/philtabor/Open-Text-Summarizer']

print(f'{len(repoList)} repos. Does not include Gather repo')
print(f'OK')
# Out:
# 9 repos. Does not include Gather repo
# OK

# %%
count = 0
for repo in repoList:
    count += 1
    repoPath = join(repo)
    localPath = join(Path.home(), basename(repo))
    if not exists(localPath):
        print(f'{count}. {localPath} Does not exist')
        Repo.clone_from(repoPath, localPath)
    elif exists(localPath):
        print(f'{count}. {localPath} already exists')
# Out:
# 1. /root/Youtube-Code-Repository already exists
# 2. /root/Actor-Critic-Methods-Paper-To-Code already exists
# 3. /root/Deep-Q-Learning-Paper-To-Code already exists
# 4. /root/Simple-Neural-Network already exists
# 5. /root/Reinforcement-Learning-In-Motion already exists
# 6. /root/PyBullet-Hand-Example already exists
# 7. /root/sensenet already exists
# 8. /root/OpenAI-Cartpole already exists
# 9. /root/Open-Text-Summarizer already exists

# %%
# allFiles = glob.glob('**', recursive=True)
allFilesDict = {}

fileCount = 0
print(f'{Path.cwd()}')
for fil in sorted(allFiles):
    realPath = realpath(fil)
    fullPath = Path(realpath(fil))
    if isdir(fullPath) and not realPath.__contains__('__pycache__'):
        print(f'\n{fullPath}')
    elif isfile(fullPath):
        fileCount += 1
        allFilesDict[fileCount] = fullPath
        print(f'{fileCount}. {fullPath}')
# Out:
# /root
#
# /root/Actor-Critic-Methods-Paper-To-Code
#
# /root/Actor-Critic-Methods-Paper-To-Code/ActorCritic
# 1. /root/Actor-Critic-Methods-Paper-To-Code/ActorCritic/actor_critic_torch.py
# 2. /root/Actor-Critic-Methods-Paper-To-Code/ActorCritic/main_lunar_lander_actor_critic.py
# 3. /root/Actor-Critic-Methods-Paper-To-Code/ActorCritic/utils.py
#
# /root/Actor-Critic-Methods-Paper-To-Code/DDPG
# 4. /root/Actor-Critic-Methods-Paper-To-Code/DDPG/buffer.py
# 5. /root/Actor-Critic-Methods-Paper-To-Code/DDPG/ddpg_torch.py
# 6. /root/Actor-Critic-Methods-Paper-To-Code/DDPG/main_ddpg.py
# 7. /root/Actor-Critic-Methods-Paper-To-Code/DDPG/networks.py
# 8. /root/Actor-Critic-Methods-Paper-To-Code/DDPG/noise.py
# 9. /root/Actor-Critic-Methods-Paper-To-Code/DDPG/utils.py
#
# /root/Actor-Critic-Methods-Paper-To-Code/Fundamentals
# 10. /root/Actor-Critic-Methods-Paper-To-Code/Fundamentals/control_blackJack_no_es.py
# 11. /root/Actor-Critic-Methods-Paper-To-Code/Fundamentals/control_cartpole_q_learning.py
# 12. /root/Actor-Critic-Methods-Paper-To-Code/Fundamentals/main_control_blackJack_no_es.py
# 13. /root/Actor-Critic-Methods-Paper-To-Code/Fundamentals/main_control_cartpole_q_learning.py
# 14. /root/Actor-Critic-Methods-Paper-To-Code/Fundamentals/main_prediction_blackJack.py
# 15. /root/Actor-Critic-Methods-Paper-To-Code/Fundamentals/prediction_blackJack.py
# 16. /root/Actor-Critic-Methods-Paper-To-Code/Fundamentals/prediction_cartpole_td_zero.py
# 17. /root/Actor-Critic-Methods-Paper-To-Code/README.md
#
# /root/Actor-Critic-Methods-Paper-To-Code/Reinforce
# 18. /root/Actor-Critic-Methods-Paper-To-Code/Reinforce/lunar_lander_random.py
# 19. /root/Actor-Critic-Methods-Paper-To-Code/Reinforce/main_lunar_lander_reinforce.py
# 20. /root/Actor-Critic-Methods-Paper-To-Code/Reinforce/reinforce_torch.py
#
# /root/Actor-Critic-Methods-Paper-To-Code/TD3
# 21. /root/Actor-Critic-Methods-Paper-To-Code/TD3/buffer.py
# 22. /root/Actor-Critic-Methods-Paper-To-Code/TD3/main_td3.py
# 23. /root/Actor-Critic-Methods-Paper-To-Code/TD3/networks.py
# 24. /root/Actor-Critic-Methods-Paper-To-Code/TD3/td3_torch.py
# 25. /root/Actor-Critic-Methods-Paper-To-Code/TD3/utils.py
#
# /root/Deep-Q-Learning-Paper-To-Code
#
# /root/Deep-Q-Learning-Paper-To-Code/DDQN
# 26. /root/Deep-Q-Learning-Paper-To-Code/DDQN/ddqn_agent.py
# 27. /root/Deep-Q-Learning-Paper-To-Code/DDQN/deep_q_network.py
# 28. /root/Deep-Q-Learning-Paper-To-Code/DDQN/main_ddqn.py
#
# /root/Deep-Q-Learning-Paper-To-Code/DDQN/models
# 29. /root/Deep-Q-Learning-Paper-To-Code/DDQN/models/PongNoFrameskip-v4_DDQNAgent_q_eval
# 30. /root/Deep-Q-Learning-Paper-To-Code/DDQN/models/PongNoFrameskip-v4_DDQNAgent_q_next
#
# /root/Deep-Q-Learning-Paper-To-Code/DDQN/plots
# 31. /root/Deep-Q-Learning-Paper-To-Code/DDQN/plots/DDQNAgent_PongNoFrameskip-v4_alpha0.0001_500games.png
# 32. /root/Deep-Q-Learning-Paper-To-Code/DDQN/replay_memory.py
# 33. /root/Deep-Q-Learning-Paper-To-Code/DDQN/utils.py
#
# /root/Deep-Q-Learning-Paper-To-Code/DQN
# 34. /root/Deep-Q-Learning-Paper-To-Code/DQN/deep_q_network.py
# 35. /root/Deep-Q-Learning-Paper-To-Code/DQN/dqn_agent.py
# 36. /root/Deep-Q-Learning-Paper-To-Code/DQN/main_dqn.py
#
# /root/Deep-Q-Learning-Paper-To-Code/DQN/models
# 37. /root/Deep-Q-Learning-Paper-To-Code/DQN/models/PongNoFrameskip-v4_DQNAgent_q_eval
# 38. /root/Deep-Q-Learning-Paper-To-Code/DQN/models/PongNoFrameskip-v4_DQNAgent_q_next
#
# /root/Deep-Q-Learning-Paper-To-Code/DQN/plots
# 39. /root/Deep-Q-Learning-Paper-To-Code/DQN/plots/DQNAgent_PongNoFrameskip-v4_alpha0.0001_500games.png
# 40. /root/Deep-Q-Learning-Paper-To-Code/DQN/preprocess_pseudocode
# 41. /root/Deep-Q-Learning-Paper-To-Code/DQN/replay_memory.py
# 42. /root/Deep-Q-Learning-Paper-To-Code/DQN/utils.py
#
# /root/Deep-Q-Learning-Paper-To-Code/DuelingDDQN
# 43. /root/Deep-Q-Learning-Paper-To-Code/DuelingDDQN/deep_q_network.py
# 44. /root/Deep-Q-Learning-Paper-To-Code/DuelingDDQN/dueling_ddqn_agent.py
# 45. /root/Deep-Q-Learning-Paper-To-Code/DuelingDDQN/main_dueling_ddqn.py
#
# /root/Deep-Q-Learning-Paper-To-Code/DuelingDDQN/models
# 46. /root/Deep-Q-Learning-Paper-To-Code/DuelingDDQN/models/PongNoFrameskip-v4_DuelingDDQNAgent_q_eval
# 47. /root/Deep-Q-Learning-Paper-To-Code/DuelingDDQN/models/PongNoFrameskip-v4_DuelingDDQNAgent_q_next
#
# /root/Deep-Q-Learning-Paper-To-Code/DuelingDDQN/plots
# 48. /root/Deep-Q-Learning-Paper-To-Code/DuelingDDQN/plots/DuelingDDQNAgent_PongNoFrameskip-v4_alpha0.0001_300games.png
# 49. /root/Deep-Q-Learning-Paper-To-Code/DuelingDDQN/replay_memory.py
# 50. /root/Deep-Q-Learning-Paper-To-Code/DuelingDDQN/utils.py
#
# /root/Deep-Q-Learning-Paper-To-Code/DuelingDQN
# 51. /root/Deep-Q-Learning-Paper-To-Code/DuelingDQN/deep_q_network.py
# 52. /root/Deep-Q-Learning-Paper-To-Code/DuelingDQN/dueling_dqn_agent.py
# 53. /root/Deep-Q-Learning-Paper-To-Code/DuelingDQN/main_dueling_dqn.py
#
# /root/Deep-Q-Learning-Paper-To-Code/DuelingDQN/models
# 54. /root/Deep-Q-Learning-Paper-To-Code/DuelingDQN/models/PongNoFrameskip-v4_DuelingDQNAgent_q_eval
# 55. /root/Deep-Q-Learning-Paper-To-Code/DuelingDQN/models/PongNoFrameskip-v4_DuelingDQNAgent_q_next
#
# /root/Deep-Q-Learning-Paper-To-Code/DuelingDQN/plots
# 56. /root/Deep-Q-Learning-Paper-To-Code/DuelingDQN/plots/DuelingDQNAgent_PongNoFrameskip-v4_alpha0.0001_300games.png
# 57. /root/Deep-Q-Learning-Paper-To-Code/DuelingDQN/replay_memory.py
# 58. /root/Deep-Q-Learning-Paper-To-Code/DuelingDQN/utils.py
# 59. /root/Deep-Q-Learning-Paper-To-Code/LICENSE
# 60. /root/Deep-Q-Learning-Paper-To-Code/README.md
# 61. /root/Deep-Q-Learning-Paper-To-Code/agents.py
# 62. /root/Deep-Q-Learning-Paper-To-Code/argparse_example.py
# 63. /root/Deep-Q-Learning-Paper-To-Code/deep_q_network.py
# 64. /root/Deep-Q-Learning-Paper-To-Code/main.py
#
# /root/Deep-Q-Learning-Paper-To-Code/naive_deep_q_learning
# 65. /root/Deep-Q-Learning-Paper-To-Code/naive_deep_q_learning/cartpole_naive_dqn.png
# 66. /root/Deep-Q-Learning-Paper-To-Code/naive_deep_q_learning/cartpole_naive_dqn.py
# 67. /root/Deep-Q-Learning-Paper-To-Code/naive_deep_q_learning/pytorch_example.py
# 68. /root/Deep-Q-Learning-Paper-To-Code/naive_deep_q_learning/util.py
#
# /root/Deep-Q-Learning-Paper-To-Code/q_learning
# 69. /root/Deep-Q-Learning-Paper-To-Code/q_learning/frozen_lake_deterministic_policy.py
# 70. /root/Deep-Q-Learning-Paper-To-Code/q_learning/frozen_lake_env_test.py
# 71. /root/Deep-Q-Learning-Paper-To-Code/q_learning/frozen_lake_q_learning.py
# 72. /root/Deep-Q-Learning-Paper-To-Code/q_learning/frozen_lake_random_agent.py
#
# /root/Deep-Q-Learning-Paper-To-Code/q_learning/plots
# 73. /root/Deep-Q-Learning-Paper-To-Code/q_learning/plots/frozen_lake_deterministic_policy.png
# 74. /root/Deep-Q-Learning-Paper-To-Code/q_learning/plots/frozen_lake_q_learning_agent.png
# 75. /root/Deep-Q-Learning-Paper-To-Code/q_learning/plots/frozen_lake_random_policy.png
# 76. /root/Deep-Q-Learning-Paper-To-Code/q_learning/q_learning_agent.py
# 77. /root/Deep-Q-Learning-Paper-To-Code/q_learning/q_network.py
# 78. /root/Deep-Q-Learning-Paper-To-Code/replay_memory.py
# 79. /root/Deep-Q-Learning-Paper-To-Code/utils.py
#
# /root/Open-Text-Summarizer
# 80. /root/Open-Text-Summarizer/AUTHORS
# 81. /root/Open-Text-Summarizer/BUGS
# 82. /root/Open-Text-Summarizer/COPYING
# 83. /root/Open-Text-Summarizer/ChangeLog
# 84. /root/Open-Text-Summarizer/HACKING
# 85. /root/Open-Text-Summarizer/INSTALL
# 86. /root/Open-Text-Summarizer/Makefile.am
# 87. /root/Open-Text-Summarizer/Makefile.in
# 88. /root/Open-Text-Summarizer/NEWS
# 89. /root/Open-Text-Summarizer/README
# 90. /root/Open-Text-Summarizer/TODO
# 91. /root/Open-Text-Summarizer/aclocal.m4
#
# /root/Open-Text-Summarizer/articles
# 92. /root/Open-Text-Summarizer/articles/Makefile.am
# 93. /root/Open-Text-Summarizer/articles/Makefile.in
# 94. /root/Open-Text-Summarizer/articles/art.hebrew.txt
# 95. /root/Open-Text-Summarizer/articles/guardian1.txt
# 96. /root/Open-Text-Summarizer/articles/gulag.txt
# 97. /root/Open-Text-Summarizer/articles/letter.txt
# 98. /root/Open-Text-Summarizer/articles/linus1.txt
# 99. /root/Open-Text-Summarizer/articles/ori.hebrew.txt
# 100. /root/Open-Text-Summarizer/articles/sacbee1.txt
# 101. /root/Open-Text-Summarizer/articles/sacbee2.txt
# 102. /root/Open-Text-Summarizer/articles/washingtonpost1.txt
# 103. /root/Open-Text-Summarizer/articles/washingtonpost2.txt
# 104. /root/Open-Text-Summarizer/articles/ynet.hebrew.txt
# 105. /root/Open-Text-Summarizer/config.guess
# 106. /root/Open-Text-Summarizer/config.sub
# 107. /root/Open-Text-Summarizer/configure
# 108. /root/Open-Text-Summarizer/configure.in
#
# /root/Open-Text-Summarizer/dic
# 109. /root/Open-Text-Summarizer/dic/Makefile.am
# 110. /root/Open-Text-Summarizer/dic/Makefile.in
# 111. /root/Open-Text-Summarizer/dic/bg.xml
# 112. /root/Open-Text-Summarizer/dic/ca.xml
# 113. /root/Open-Text-Summarizer/dic/cs.xml
# 114. /root/Open-Text-Summarizer/dic/cy.xml
# 115. /root/Open-Text-Summarizer/dic/da.xml
# 116. /root/Open-Text-Summarizer/dic/de.xml
# 117. /root/Open-Text-Summarizer/dic/el.xml
# 118. /root/Open-Text-Summarizer/dic/en.xml
# 119. /root/Open-Text-Summarizer/dic/eo.xml
# 120. /root/Open-Text-Summarizer/dic/es.xml
# 121. /root/Open-Text-Summarizer/dic/et.xml
# 122. /root/Open-Text-Summarizer/dic/eu.xml
# 123. /root/Open-Text-Summarizer/dic/fi.xml
# 124. /root/Open-Text-Summarizer/dic/fr.xml
# 125. /root/Open-Text-Summarizer/dic/ga.xml
# 126. /root/Open-Text-Summarizer/dic/gl.xml
# 127. /root/Open-Text-Summarizer/dic/he.xml
# 128. /root/Open-Text-Summarizer/dic/hu.xml
# 129. /root/Open-Text-Summarizer/dic/ia.xml
# 130. /root/Open-Text-Summarizer/dic/id.xml
# 131. /root/Open-Text-Summarizer/dic/is.xml
# 132. /root/Open-Text-Summarizer/dic/it.xml
# 133. /root/Open-Text-Summarizer/dic/lv.xml
# 134. /root/Open-Text-Summarizer/dic/mi.xml
# 135. /root/Open-Text-Summarizer/dic/ms.xml
# 136. /root/Open-Text-Summarizer/dic/mt.xml
# 137. /root/Open-Text-Summarizer/dic/nl.xml
# 138. /root/Open-Text-Summarizer/dic/nn.xml
# 139. /root/Open-Text-Summarizer/dic/pl.xml
# 140. /root/Open-Text-Summarizer/dic/pt.xml
# 141. /root/Open-Text-Summarizer/dic/ro.xml
# 142. /root/Open-Text-Summarizer/dic/ru.xml
# 143. /root/Open-Text-Summarizer/dic/sv.xml
# 144. /root/Open-Text-Summarizer/dic/tl.xml
# 145. /root/Open-Text-Summarizer/dic/tr.xml
# 146. /root/Open-Text-Summarizer/dic/uk.xml
# 147. /root/Open-Text-Summarizer/dic/yi.xml
#
# /root/Open-Text-Summarizer/doc
# 148. /root/Open-Text-Summarizer/doc/Makefile.am
# 149. /root/Open-Text-Summarizer/doc/Makefile.in
# 150. /root/Open-Text-Summarizer/doc/ots-docs.sgml
# 151. /root/Open-Text-Summarizer/doc/ots-overrides.txt
# 152. /root/Open-Text-Summarizer/doc/ots-sections.txt
# 153. /root/Open-Text-Summarizer/install-sh
# 154. /root/Open-Text-Summarizer/libots-1.pc.in
# 155. /root/Open-Text-Summarizer/ltmain.sh
# 156. /root/Open-Text-Summarizer/missing
# 157. /root/Open-Text-Summarizer/mkinstalldirs
# 158. /root/Open-Text-Summarizer/ots-config.h.in
# 159. /root/Open-Text-Summarizer/ots.spec
# 160. /root/Open-Text-Summarizer/ots.spec.in
#
# /root/Open-Text-Summarizer/src
# 161. /root/Open-Text-Summarizer/src/Makefile.am
# 162. /root/Open-Text-Summarizer/src/Makefile.in
# 163. /root/Open-Text-Summarizer/src/article.c
# 164. /root/Open-Text-Summarizer/src/dictionary.c
# 165. /root/Open-Text-Summarizer/src/grader-tc.c
# 166. /root/Open-Text-Summarizer/src/grader-tc.h
# 167. /root/Open-Text-Summarizer/src/grader-tf.c
# 168. /root/Open-Text-Summarizer/src/grader.c
# 169. /root/Open-Text-Summarizer/src/highlighter.c
# 170. /root/Open-Text-Summarizer/src/html.c
# 171. /root/Open-Text-Summarizer/src/libots.h
# 172. /root/Open-Text-Summarizer/src/ots.c
# 173. /root/Open-Text-Summarizer/src/parser.c
# 174. /root/Open-Text-Summarizer/src/relations.c
# 175. /root/Open-Text-Summarizer/src/stemmer.c
# 176. /root/Open-Text-Summarizer/src/text.c
# 177. /root/Open-Text-Summarizer/src/wordlist.c
# 178. /root/Open-Text-Summarizer/stamp-h.in
#
# /root/OpenAI-Cartpole
# 179. /root/OpenAI-Cartpole/cartpole_qlearning.py
# 180. /root/OpenAI-Cartpole/readme.txt
#
# /root/PyBullet-Hand-Example
# 181. /root/PyBullet-Hand-Example/MPL.xml
# 182. /root/PyBullet-Hand-Example/MPL_index_only.xml
# 183. /root/PyBullet-Hand-Example/README.md
# 184. /root/PyBullet-Hand-Example/file.stl
# 185. /root/PyBullet-Hand-Example/finger_demo.py
# 186. /root/PyBullet-Hand-Example/hand_fingers_curled.py
# 187. /root/PyBullet-Hand-Example/hand_index_only.py
# 188. /root/PyBullet-Hand-Example/hand_with_debug_line.py
# 189. /root/PyBullet-Hand-Example/loader.stl.urdf
#
# /root/PyBullet-Hand-Example/mesh
# 190. /root/PyBullet-Hand-Example/mesh/index0.stl
# 191. /root/PyBullet-Hand-Example/mesh/index0_collision.stl
# 192. /root/PyBullet-Hand-Example/mesh/index1.stl
# 193. /root/PyBullet-Hand-Example/mesh/index1_collision.stl
# 194. /root/PyBullet-Hand-Example/mesh/index2.stl
# 195. /root/PyBullet-Hand-Example/mesh/index2_collision.stl
# 196. /root/PyBullet-Hand-Example/mesh/index3.stl
# 197. /root/PyBullet-Hand-Example/mesh/index3_collision.stl
# 198. /root/PyBullet-Hand-Example/mesh/middle0.stl
# 199. /root/PyBullet-Hand-Example/mesh/middle0_collision.stl
# 200. /root/PyBullet-Hand-Example/mesh/middle1.stl
# 201. /root/PyBullet-Hand-Example/mesh/middle1_collision.stl
# 202. /root/PyBullet-Hand-Example/mesh/middle2.stl
# 203. /root/PyBullet-Hand-Example/mesh/middle2_collision.stl
# 204. /root/PyBullet-Hand-Example/mesh/middle3.stl
# 205. /root/PyBullet-Hand-Example/mesh/middle3_collision.stl
# 206. /root/PyBullet-Hand-Example/mesh/palm.stl
# 207. /root/PyBullet-Hand-Example/mesh/palm_collision.stl
# 208. /root/PyBullet-Hand-Example/mesh/pinky0.stl
# 209. /root/PyBullet-Hand-Example/mesh/pinky0_collision.stl
# 210. /root/PyBullet-Hand-Example/mesh/pinky1.stl
# 211. /root/PyBullet-Hand-Example/mesh/pinky1_collision.stl
# 212. /root/PyBullet-Hand-Example/mesh/pinky2.stl
# 213. /root/PyBullet-Hand-Example/mesh/pinky2_collision.stl
# 214. /root/PyBullet-Hand-Example/mesh/pinky3.stl
# 215. /root/PyBullet-Hand-Example/mesh/pinky3_collision.stl
# 216. /root/PyBullet-Hand-Example/mesh/ring0.stl
# 217. /root/PyBullet-Hand-Example/mesh/ring0_collision.stl
# 218. /root/PyBullet-Hand-Example/mesh/ring1.stl
# 219. /root/PyBullet-Hand-Example/mesh/ring1_collision.stl
# 220. /root/PyBullet-Hand-Example/mesh/ring2.stl
# 221. /root/PyBullet-Hand-Example/mesh/ring2_collision.stl
# 222. /root/PyBullet-Hand-Example/mesh/ring3.stl
# 223. /root/PyBullet-Hand-Example/mesh/ring3_collision.stl
# 224. /root/PyBullet-Hand-Example/mesh/thumb0.stl
# 225. /root/PyBullet-Hand-Example/mesh/thumb0_collision.stl
# 226. /root/PyBullet-Hand-Example/mesh/thumb1.stl
# 227. /root/PyBullet-Hand-Example/mesh/thumb1_collision.stl
# 228. /root/PyBullet-Hand-Example/mesh/thumb2.stl
# 229. /root/PyBullet-Hand-Example/mesh/thumb2_collision.stl
# 230. /root/PyBullet-Hand-Example/mesh/thumb3.stl
# 231. /root/PyBullet-Hand-Example/mesh/thumb3_collision.stl
# 232. /root/PyBullet-Hand-Example/mesh/wristx.stl
# 233. /root/PyBullet-Hand-Example/mesh/wristx_collision.stl
# 234. /root/PyBullet-Hand-Example/mesh/wristy.stl
# 235. /root/PyBullet-Hand-Example/mesh/wristy_collision.stl
# 236. /root/PyBullet-Hand-Example/mesh/wristz.stl
# 237. /root/PyBullet-Hand-Example/mesh/wristz_collision.stl
#
# /root/Reinforcement-Learning-In-Motion
# 238. /root/Reinforcement-Learning-In-Motion/README.md
#
# /root/Reinforcement-Learning-In-Motion/Unit-2-The-Maze-Running-Robot
# 239. /root/Reinforcement-Learning-In-Motion/Unit-2-The-Maze-Running-Robot/agent.py
# 240. /root/Reinforcement-Learning-In-Motion/Unit-2-The-Maze-Running-Robot/environment.py
# 241. /root/Reinforcement-Learning-In-Motion/Unit-2-The-Maze-Running-Robot/main.py
#
# /root/Reinforcement-Learning-In-Motion/Unit-3-The-Multi-Armed-Bandit
# 242. /root/Reinforcement-Learning-In-Motion/Unit-3-The-Multi-Armed-Bandit/bandit.py
# 243. /root/Reinforcement-Learning-In-Motion/Unit-3-The-Multi-Armed-Bandit/bandit_non_stationary_rewards.py
# 244. /root/Reinforcement-Learning-In-Motion/Unit-3-The-Multi-Armed-Bandit/bandit_optimistic.py
# 245. /root/Reinforcement-Learning-In-Motion/Unit-3-The-Multi-Armed-Bandit/bandit_ucb.py
#
# /root/Reinforcement-Learning-In-Motion/Unit-4-The-Frozen-Lake
# 246. /root/Reinforcement-Learning-In-Motion/Unit-4-The-Frozen-Lake/agent.py
# 247. /root/Reinforcement-Learning-In-Motion/Unit-4-The-Frozen-Lake/env_demo.py
# 248. /root/Reinforcement-Learning-In-Motion/Unit-4-The-Frozen-Lake/env_demo.py.save
# 249. /root/Reinforcement-Learning-In-Motion/Unit-4-The-Frozen-Lake/main.py
#
# /root/Reinforcement-Learning-In-Motion/Unit-5-The-Gridworld
# 250. /root/Reinforcement-Learning-In-Motion/Unit-5-The-Gridworld/grid.py
# 251. /root/Reinforcement-Learning-In-Motion/Unit-5-The-Gridworld/gridWithMoves.py
# 252. /root/Reinforcement-Learning-In-Motion/Unit-5-The-Gridworld/main.py
# 253. /root/Reinforcement-Learning-In-Motion/Unit-5-The-Gridworld/mainWithMoves.py
# 254. /root/Reinforcement-Learning-In-Motion/Unit-5-The-Gridworld/policyEvaluation.py
# 255. /root/Reinforcement-Learning-In-Motion/Unit-5-The-Gridworld/policyEvaluationWithMoves.py
# 256. /root/Reinforcement-Learning-In-Motion/Unit-5-The-Gridworld/policyImprovement.py
# 257. /root/Reinforcement-Learning-In-Motion/Unit-5-The-Gridworld/policyImprovementWithMoves.py
# 258. /root/Reinforcement-Learning-In-Motion/Unit-5-The-Gridworld/utils.py
# 259. /root/Reinforcement-Learning-In-Motion/Unit-5-The-Gridworld/valueIteration.py
# 260. /root/Reinforcement-Learning-In-Motion/Unit-5-The-Gridworld/valueIterationWithMoves.py
#
# /root/Reinforcement-Learning-In-Motion/Unit-6-The-Windy-Gridworld
# 261. /root/Reinforcement-Learning-In-Motion/Unit-6-The-Windy-Gridworld/__pycache__/grid.cpython-36.pyc
# 262. /root/Reinforcement-Learning-In-Motion/Unit-6-The-Windy-Gridworld/__pycache__/utils.cpython-36.pyc
# 263. /root/Reinforcement-Learning-In-Motion/Unit-6-The-Windy-Gridworld/__pycache__/windygrid.cpython-36.pyc
# 264. /root/Reinforcement-Learning-In-Motion/Unit-6-The-Windy-Gridworld/exploringStarts.py
# 265. /root/Reinforcement-Learning-In-Motion/Unit-6-The-Windy-Gridworld/firstVisit.py
# 266. /root/Reinforcement-Learning-In-Motion/Unit-6-The-Windy-Gridworld/frozen-lake.py
# 267. /root/Reinforcement-Learning-In-Motion/Unit-6-The-Windy-Gridworld/offPolicyControl.py
# 268. /root/Reinforcement-Learning-In-Motion/Unit-6-The-Windy-Gridworld/offPolicyPrediction.py
# 269. /root/Reinforcement-Learning-In-Motion/Unit-6-The-Windy-Gridworld/utils.py
# 270. /root/Reinforcement-Learning-In-Motion/Unit-6-The-Windy-Gridworld/windygrid.py
# 271. /root/Reinforcement-Learning-In-Motion/Unit-6-The-Windy-Gridworld/withoutExploringStarts.py
#
# /root/Reinforcement-Learning-In-Motion/Unit-7-The-Cartpole
# 272. /root/Reinforcement-Learning-In-Motion/Unit-7-The-Cartpole/compareQLearningvsDoubleQLearning.py
# 273. /root/Reinforcement-Learning-In-Motion/Unit-7-The-Cartpole/compareQLearningvsSARSA.py
# 274. /root/Reinforcement-Learning-In-Motion/Unit-7-The-Cartpole/doubleQLearning.py
# 275. /root/Reinforcement-Learning-In-Motion/Unit-7-The-Cartpole/intro.py
# 276. /root/Reinforcement-Learning-In-Motion/Unit-7-The-Cartpole/qlearning.py
# 277. /root/Reinforcement-Learning-In-Motion/Unit-7-The-Cartpole/sarsa.py
# 278. /root/Reinforcement-Learning-In-Motion/Unit-7-The-Cartpole/tdZero.py
# 279. /root/Reinforcement-Learning-In-Motion/Unit-7-The-Cartpole/util.py
#
# /root/Reinforcement-Learning-In-Motion/Unit-8-The-Mountaincar
# 280. /root/Reinforcement-Learning-In-Motion/Unit-8-The-Mountaincar/approxMonteCarlo.py
# 281. /root/Reinforcement-Learning-In-Motion/Unit-8-The-Mountaincar/mountainCar.py
# 282. /root/Reinforcement-Learning-In-Motion/Unit-8-The-Mountaincar/semiGradientSarsaControl.py
# 283. /root/Reinforcement-Learning-In-Motion/Unit-8-The-Mountaincar/tdZeroApprox.py
#
# /root/Reinforcement-Learning-In-Motion/Unit-8-The-Mountaincar/testScripts
# 284. /root/Reinforcement-Learning-In-Motion/Unit-8-The-Mountaincar/testScripts/testTiles.py
# 285. /root/Reinforcement-Learning-In-Motion/Unit-8-The-Mountaincar/testScripts/velocityTest.py
#
# /root/Simple-Neural-Network
# 286. /root/Simple-Neural-Network/README.md
# 287. /root/Simple-Neural-Network/nn2.py
#
# /root/Youtube-Code-Repository
# 288. /root/Youtube-Code-Repository/CNN.py
#
# /root/Youtube-Code-Repository/Kaggle
# 289. /root/Youtube-Code-Repository/Kaggle/venus-volcanoes.ipynb
# 290. /root/Youtube-Code-Repository/README.md
#
# /root/Youtube-Code-Repository/ReinforcementLearning
#
# /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning
# 291. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/ddqn_keras.py
# 292. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/dqn_keras.py
# 293. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/dqn_tf.py
# 294. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/dueling_ddqn_tf2.py
# 295. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/dueling_ddqn_torch.py
# 296. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/dueling_dqn_keras.py
# 297. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/dueling_dqn_torch.py
# 298. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/frame_stack_test.py
# 299. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/main_keras_ddqn_lunar_lander.py
# 300. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/main_keras_dqn_lunar_lander.py
# 301. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/main_keras_dqn_pong.py
# 302. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/main_keras_dueling_dqn_lunar_lander.py
# 303. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/main_tf2_dqn_lunar_lander.py
# 304. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/main_tf2_dueling_ddqn_lunar_lander.py
# 305. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/main_tf_dqn_breakout.py
# 306. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/main_tf_dqn_lunar_lander.py
# 307. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/main_torch_dqn_lunar_lander.py
# 308. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/main_torch_dqn_lunar_lander_2020.py
# 309. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/main_torch_dqn_space_invaders.py
# 310. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/main_torch_dueling_ddqn_lunar_lander.py
# 311. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/main_torch_dueling_dqn_lunar_lander.py
# 312. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/q_eval.h5
# 313. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/q_next.h5
# 314. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/simple_dqn_keras.py
# 315. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/simple_dqn_tf.py
# 316. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/simple_dqn_tf2.py
# 317. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/simple_dqn_torch.py
# 318. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/simple_dqn_torch_2020.py
# 319. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/torch_deep_q_model.py
# 320. /root/Youtube-Code-Repository/ReinforcementLearning/DeepQLearning/utils.py
#
# /root/Youtube-Code-Repository/ReinforcementLearning/Fundamentals
# 321. /root/Youtube-Code-Repository/ReinforcementLearning/Fundamentals/acrobot.py
# 322. /root/Youtube-Code-Repository/ReinforcementLearning/Fundamentals/blackJack-no-es.py
# 323. /root/Youtube-Code-Repository/ReinforcementLearning/Fundamentals/blackJack-off-policy.py
# 324. /root/Youtube-Code-Repository/ReinforcementLearning/Fundamentals/cartpole_qlearning.py
# 325. /root/Youtube-Code-Repository/ReinforcementLearning/Fundamentals/doubleQLearning.py
# 326. /root/Youtube-Code-Repository/ReinforcementLearning/Fundamentals/dynamic_programming.py
# 327. /root/Youtube-Code-Repository/ReinforcementLearning/Fundamentals/gridworld.py
# 328. /root/Youtube-Code-Repository/ReinforcementLearning/Fundamentals/mountaincar.png
# 329. /root/Youtube-Code-Repository/ReinforcementLearning/Fundamentals/mountaincar.py
# 330. /root/Youtube-Code-Repository/ReinforcementLearning/Fundamentals/n_step_sarsa.py
# 331. /root/Youtube-Code-Repository/ReinforcementLearning/Fundamentals/sarsa.py
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/lunar-lander
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/lunar-lander/pytorch
# 332. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/lunar-lander/pytorch/Torch-LunarLander-alpha000025-beta00025-400-300.png
# 333. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/lunar-lander/pytorch/ddpg_torch.py
# 334. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/lunar-lander/pytorch/main_torch.py
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/lunar-lander/pytorch/tmp
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/lunar-lander/pytorch/tmp/ddpg
# 335. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/lunar-lander/pytorch/tmp/ddpg/Actor_ddpg
# 336. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/lunar-lander/pytorch/tmp/ddpg/Critic_ddpg
# 337. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/lunar-lander/pytorch/tmp/ddpg/TargetActor_ddpg
# 338. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/lunar-lander/pytorch/tmp/ddpg/TargetCritic_ddpg
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/pendulum
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/pendulum/tensorflow
# 339. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/pendulum/tensorflow/ddpg_orig_tf.py
# 340. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/pendulum/tensorflow/main_tf.py
# 341. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/pendulum/tensorflow/utils.py
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow
# 342. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/ddpg_orig_tf.py
# 343. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/main_tf.py
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp/ddpg_best_3
# 344. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp/ddpg_best_3/Actor_ddpg.ckpt.data-00000-of-00001
# 345. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp/ddpg_best_3/Actor_ddpg.ckpt.index
# 346. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp/ddpg_best_3/Actor_ddpg.ckpt.meta
# 347. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp/ddpg_best_3/Critic_ddpg.ckpt.data-00000-of-00001
# 348. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp/ddpg_best_3/Critic_ddpg.ckpt.index
# 349. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp/ddpg_best_3/Critic_ddpg.ckpt.meta
# 350. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp/ddpg_best_3/TargetActor_ddpg.ckpt.data-00000-of-00001
# 351. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp/ddpg_best_3/TargetActor_ddpg.ckpt.index
# 352. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp/ddpg_best_3/TargetActor_ddpg.ckpt.meta
# 353. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp/ddpg_best_3/TargetCritic_ddpg.ckpt.data-00000-of-00001
# 354. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp/ddpg_best_3/TargetCritic_ddpg.ckpt.index
# 355. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp/ddpg_best_3/TargetCritic_ddpg.ckpt.meta
# 356. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/DDPG/walker2d/tensorflow/tmp/ddpg_best_3/checkpoint
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/TD3
# 357. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/TD3/main.py
# 358. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/TD3/td3_torch.py
# 359. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/TD3/utils.py
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/actor_critic
# 360. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/actor_critic/actor_critic_continuous.py
# 361. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/actor_critic/actor_critic_keras.py
# 362. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/actor_critic/actor_critic_replay_torch.py
# 363. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/actor_critic/cartpole-discrete-actor-critic-alpha0001-beta0005-32x32fc.png
# 364. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/actor_critic/continuous_mountain_car_actor_critic.py
# 365. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/actor_critic/discrete_cartpole.py
# 366. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/actor_critic/main_keras_actor_critic_lunar_lander.py
# 367. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/actor_critic/main_torch_actor_critic_replay_lunar_lander.py
# 368. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/actor_critic/mountaincar-continuous-old-actor-critic-alpha000005-256x256fc-100games.png
# 369. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/actor_critic/torch_actor_critic_discrete.py
# 370. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/actor_critic/torch_discrete_lunar_lander.py
# 371. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/actor_critic/utils.py
#
# /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/reinforce
# 372. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/reinforce/main_keras_reinforce_lunar_lander.py
# 373. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/reinforce/main_tf_reinforce_lunar_lander.py
# 374. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/reinforce/main_tf_reinforce_space_invaders.py
# 375. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/reinforce/main_torch_reinforce_lunar_lander.py
# 376. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/reinforce/reinforce_cnn_tf.py
# 377. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/reinforce/reinforce_keras.py
# 378. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/reinforce/reinforce_tf.py
# 379. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/reinforce/reinforce_torch.py
# 380. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/reinforce/space-invaders-alpha001-gamma0p9-decay0p99-newGcalc.png
# 381. /root/Youtube-Code-Repository/ReinforcementLearning/PolicyGradient/reinforce/utils.py
# 382. /root/Youtube-Code-Repository/cmdline.py
# 383. /root/Youtube-Code-Repository/modular_cnn.py
# 384. /root/Youtube-Code-Repository/simple_cnn_mnist.py
# 385. /root/Youtube-Code-Repository/simple_nn_mnist.py
# 386. /root/Youtube-Code-Repository/tf_embeddings.py
# 387. /root/Youtube-Code-Repository/tf_sentiment.py
# 388. /root/Youtube-Code-Repository/tf_text_gen.py
# 389. /root/Youtube-Code-Repository/threaded.py
#
# /root/sensenet
# 390. /root/sensenet/Dockerfile
# 391. /root/sensenet/LICENSE
# 392. /root/sensenet/MANIFEST.in
# 393. /root/sensenet/README.md
# 394. /root/sensenet/Vagrantfile
#
# /root/sensenet/agents
# 395. /root/sensenet/agents/dqn_tensorflow.py
# 396. /root/sensenet/agents/launch_reinforce.sh
# 397. /root/sensenet/agents/pytorch_cnn.py
# 398. /root/sensenet/agents/random-agent.py
# 399. /root/sensenet/agents/reinforce.py
# 400. /root/sensenet/agents/touch_classification.py
#
# /root/sensenet/images
# 401. /root/sensenet/images/dataset.png
# 402. /root/sensenet/images/gestures.png
# 403. /root/sensenet/images/hand.png
#
# /root/sensenet/provision
#
# /root/sensenet/provision/services
# 404. /root/sensenet/provision/services/xfce.service
# 405. /root/sensenet/provision/setup.sh
# 406. /root/sensenet/requirements.txt
#
# /root/sensenet/scripts
# 407. /root/sensenet/scripts/action.py
# 408. /root/sensenet/scripts/generate_touches.py
# 409. /root/sensenet/scripts/generate_wand_touches.py
# 410. /root/sensenet/scripts/load_obj.py
# 411. /root/sensenet/scripts/record.py
# 412. /root/sensenet/scripts/run.py
# 413. /root/sensenet/scripts/signs.py
# 414. /root/sensenet/scripts/touch_test.py
#
# /root/sensenet/sensenet
# 415. /root/sensenet/sensenet/__init__.py
# 416. /root/sensenet/sensenet/configuration.py
# 417. /root/sensenet/sensenet/core.py
#
# /root/sensenet/sensenet/envs
# 418. /root/sensenet/sensenet/envs/__init__.py
#
# /root/sensenet/sensenet/envs/handroid
# 419. /root/sensenet/sensenet/envs/handroid/__init__.py
# 420. /root/sensenet/sensenet/envs/handroid/blank_env.py
#
# /root/sensenet/sensenet/envs/handroid/data
#
# /root/sensenet/sensenet/envs/handroid/data/MPL
# 421. /root/sensenet/sensenet/envs/handroid/data/MPL/LICENSE.txt
# 422. /root/sensenet/sensenet/envs/handroid/data/MPL/MPL.xml
# 423. /root/sensenet/sensenet/envs/handroid/data/MPL/MPL_index_only.xml
#
# /root/sensenet/sensenet/envs/handroid/data/MPL/mesh
# 424. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/index0.stl
# 425. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/index0_collision.stl
# 426. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/index1.stl
# 427. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/index1_collision.stl
# 428. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/index2.stl
# 429. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/index2_collision.stl
# 430. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/index3.stl
# 431. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/index3_collision.stl
# 432. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/middle0.stl
# 433. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/middle0_collision.stl
# 434. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/middle1.stl
# 435. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/middle1_collision.stl
# 436. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/middle2.stl
# 437. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/middle2_collision.stl
# 438. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/middle3.stl
# 439. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/middle3_collision.stl
# 440. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/palm.stl
# 441. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/palm_collision.stl
# 442. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/pinky0.stl
# 443. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/pinky0_collision.stl
# 444. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/pinky1.stl
# 445. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/pinky1_collision.stl
# 446. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/pinky2.stl
# 447. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/pinky2_collision.stl
# 448. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/pinky3.stl
# 449. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/pinky3_collision.stl
# 450. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/ring0.stl
# 451. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/ring0_collision.stl
# 452. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/ring1.stl
# 453. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/ring1_collision.stl
# 454. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/ring2.stl
# 455. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/ring2_collision.stl
# 456. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/ring3.stl
# 457. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/ring3_collision.stl
# 458. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/thumb0.stl
# 459. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/thumb0_collision.stl
# 460. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/thumb1.stl
# 461. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/thumb1_collision.stl
# 462. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/thumb2.stl
# 463. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/thumb2_collision.stl
# 464. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/thumb3.stl
# 465. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/thumb3_collision.stl
# 466. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/wristx.stl
# 467. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/wristx_collision.stl
# 468. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/wristy.stl
# 469. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/wristy_collision.stl
# 470. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/wristz.stl
# 471. /root/sensenet/sensenet/envs/handroid/data/MPL/mesh/wristz_collision.stl
# 472. /root/sensenet/sensenet/envs/handroid/data/MPL/mpl2.xml
# 473. /root/sensenet/sensenet/envs/handroid/data/circle.stl
# 474. /root/sensenet/sensenet/envs/handroid/data/key.stl
# 475. /root/sensenet/sensenet/envs/handroid/data/loader.obj.urdf
# 476. /root/sensenet/sensenet/envs/handroid/data/loader.stl.urdf
# 477. /root/sensenet/sensenet/envs/handroid/data/mesh.urdf
# 478. /root/sensenet/sensenet/envs/handroid/data/pyramid.stl
# 479. /root/sensenet/sensenet/envs/handroid/exp_hand_env.py
# 480. /root/sensenet/sensenet/envs/handroid/hand_env.py
# 481. /root/sensenet/sensenet/envs/handroid/index_finger_hand_env.py
# 482. /root/sensenet/sensenet/envs/handroid/index_finger_only_hand_env.py
# 483. /root/sensenet/sensenet/envs/handroid/survive_env.py
# 484. /root/sensenet/sensenet/envs/handroid/touch_wand_env.py
# 485. /root/sensenet/sensenet/envs/registration.py
# 486. /root/sensenet/sensenet/error.py
#
# /root/sensenet/sensenet/scoreboard
# 487. /root/sensenet/sensenet/scoreboard/api.py
#
# /root/sensenet/sensenet/spaces
# 488. /root/sensenet/sensenet/spaces/__init__.py
# 489. /root/sensenet/sensenet/spaces/box.py
# 490. /root/sensenet/sensenet/spaces/discrete.py
# 491. /root/sensenet/sensenet/spaces/prng.py
#
# /root/sensenet/sensenet/utils
# 492. /root/sensenet/sensenet/utils/closer.py
# 493. /root/sensenet/sensenet/utils/mkdir_p.py
# 494. /root/sensenet/sensenet/utils/reraise.py
# 495. /root/sensenet/sensenet/utils/reraise_impl_py2.py
# 496. /root/sensenet/sensenet/utils/reraise_impl_py3.py
# 497. /root/sensenet/sensenet/version.py
#
# /root/sensenet/sensenet/wrappers
# 498. /root/sensenet/sensenet/wrappers/__init__.py
# 499. /root/sensenet/sensenet/wrappers/time_limit.py
# 500. /root/sensenet/setup.py
#
# /root/sensenet/tests
#
# /root/sensenet/tests/data
# 501. /root/sensenet/tests/data/cube.stl
#
# /root/sensenet/tests/data/good_folder
#
# /root/sensenet/tests/data/good_folder/2
#
# /root/sensenet/tests/data/good_folder/2/123
# 502. /root/sensenet/tests/data/good_folder/2/123/cube.stl
# 503. /root/sensenet/tests/data/good_folder/2/123/pyramid.stl
# 504. /root/sensenet/tests/data/pyramid.stl
# 505. /root/sensenet/tests/data/sphere.stl
#
# /root/sensenet/tests/envs
# 506. /root/sensenet/tests/envs/my_env.py
# 507. /root/sensenet/tests/requirements_test.txt
# 508. /root/sensenet/tests/test_env.py
# 509. /root/sensenet/tests/test_envs.py
# 510. /root/sensenet/tests/test_path.py

# %%
pth = allFilesDict[1]
print(f'# %%writefile {pth.name}\n')
try:
    with open(pth, 'r') as openFile:
        print(openFile.read())
except:
    try:
        with open(pth, 'rb') as openFile:
            readLines = openFile.readlines()
            for line in readLines:
                print(f'{C.LITE}')
                print(line)
    except Exception as exc:
        print(exc)
        print(f'BULLSHIT')
# Out:
# # %%writefile README.md
#
# This directory includes a few sample datasets to get you started.
#
# *   `california_housing_data*.csv` is California housing data from the 1990 US
#     Census; more information is available at:
#     https://developers.google.com/machine-learning/crash-course/california-housing-data-description
#
# *   `mnist_*.csv` is a small sample of the
#     [MNIST database](https://en.wikipedia.org/wiki/MNIST_database), which is
#     described at: http://yann.lecun.com/exdb/mnist/
#
# *   `anscombe.json` contains a copy of
#     [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet); it
#     was originally described in
#
#     Anscombe, F. J. (1973). 'Graphs in Statistical Analysis'. American
#     Statistician. 27 (1): 17-21. JSTOR 2682899.
#
#     and our copy was prepared by the
#     [vega_datasets library](https://github.com/altair-viz/vega_datasets/blob/4f67bdaad10f45e3549984e17e1b3088c731503d/vega_datasets/_data/anscombe.json).
