# %%
from __future__ import absolute_import, division
from IPython.display import clear_output
from BashColors import C
from TarfileFunctions import *

import glob, json, os, sys
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '5'
from os.path import *
from time import perf_counter, perf_counter_ns

contentPath = os.getcwd()
genPath = join(contentPath, 'DataGenerator')
testPath = join(contentPath, 'images')
jsonPath = join(contentPath, 'initialGlobList.json')

if not exists(genPath):
    tff.extractTarfiles('DataGenerator5.tar.gz')
if not exists(testPath):
    tff.extractTarfiles('images.tar.gz')

from time import perf_counter, sleep
import concurrent.futures

initialGlobList=glob.glob('**')
if not 'initialGlobList.json' in initialGlobList:
    initialGlobList.append('initialGlobList.json')

with open("initialGlobList.json", 'w') as f:
    # indent=2 is not needed but makes the file human-readable
    json.dump(initialGlobList, f) # indent=2

initialGlobList:list
with open("initialGlobList.json", 'r') as f:
    initialGlobList = json.load(f)
    
def listNewFiles(initial=initialGlobList, delete=False):
    currentFilesGlob=glob.glob('**')
    if len(initial) == len(currentFilesGlob):
        print(f'{C.BIRed}Nothing to see here.\nNo new files.')
    for fil in currentFilesGlob:
        if not fil in initial:
            if isdir(fil):
                print(f'{C.BIBlue}{fil}')
                if delete:
                    shutil.rmtree(fil)
            elif isfile(fil):
                print(f'{C.ColorOff}{fil}')
                if delete:
                    os.remove(fil)
listNewFiles()

# %%
with open("initialGlobList.json", 'r') as f:
    initialGlobList = json.load(f)
    fileCount=0
    for fil in initialGlobList:
        fileCount+=1
        # print(fil)
print(f'{fileCount}{C.BIBlue} files in contentPath')

# %%
def printTime(strt, fin):
    '''print execution times '''
    totalTime = fin - strt
    totalTime= round(totalTime, 0)
    if totalTime < 60.0:
        print(f'{C.BIBlue}')
        print(f'completed: {totalTime} second(s)')
    elif totalTime >= 60.0:
        minutes = totalTime//60
        seconds = totalTime - (minutes * 60)
        seconds = round(seconds, 2)
        print(f'{C.BIBlue}')
        print(f'completed: {minutes} minutes {seconds} second(s)')

def getTensorflow():
    # %pip install -q tensorflow
    print(f'installed: {C.BIBlue}tensorflow{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}tensorflow{C.ColorOff}'

def getTensorflowDatasets():
    # %pip install -q tensorflow-datasets
    print(f'installed: {C.BIBlue}tensorflow-datasets{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}tensorflow-datasets{C.ColorOff}'

def getTFLiteModelMaker():
    # %pip install -q tflite-model-maker
    print(f'installed: {C.BIBlue}tflite-model-maker{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}tflite-model-maker{C.ColorOff}'

def getTFHub():
    # %pip install -q --upgrade tensorflow-hub
    print(f'installed: {C.BIBlue}tensorflow-hub{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}tensorflow-hub{C.ColorOff}'

def getTFLiteSupport():
    # %pip install -q --upgrade tflite-support
    print(f'installed: {C.BIBlue}tflite-support{C.ColorOff}')
    return f'installed: {C.BIBlue}tflite-support{C.ColorOff}'

def getTFLiteRuntime():
    # %pip install -q --upgrade tflite-runtime
    print(f'installed: {C.BIBlue}tflite-runtime{C.ColorOff}')
    return f'installed: {C.BIBlue}tflite-runtime{C.ColorOff}'

def getNumpy():
    # %pip install -q numpy
    print(f'installed: {C.BIBlue}numpy{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}numpy{C.ColorOff}'
    
def getCV2():
    # %pip install -q opencv-python-headless # works.
    print(f'installed: {C.BIBlue}opencv-headless{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}opencv-headless{C.ColorOff}'
    # %pip install -q opencv-contrib-python-headless

def getMatplotlib():
    # %pip install -q matplotlib
    print(f'installed: {C.BIBlue}matplotlib{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}matplotlib{C.ColorOff}'
    
def getSciPi():
    # %pip install -q SciPy
    print(f'installed: {C.BIBlue}SciPy{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}SciPy{C.ColorOff}'

def getSeaborn():
    # %pip install -q seaborn
    print(f'installed: {C.BIBlue}seaborn{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}seaborn{C.ColorOff}'

def getResults():
    # %pip install -q --upgrade results
    print(f'installed: {C.BIBlue}results{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}results{C.ColorOff}'

def getBeautifulSoup():
    ''' '''
    # %pip install -q beautifulsoup4
    print(f'installed: {C.BIBlue}beautifulsoup4{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}beautifulsoup4{C.ColorOff}'

def get_htmlib():
    '''USED WITH BeautifulSoup'''
    # %pip install -q html5lib
    print(f'installed: {C.BIBlue}html5lib{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}html5lib{C.ColorOff}'

def get_lxml():
    '''USED WITH BeautifulSoup'''
    # %pip install -q lxml
    print(f'installed: {C.BIBlue}lxml{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}lxml{C.ColorOff}'

def getImutils():
    '''Image processing utility '''
    # %pip install -q imutils
    print(f'installed: {C.BIBlue}imutils{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}imutils{C.ColorOff}'

def getPillow():
    '''Image processing utility '''
    # %pip install -q pillow
    print(f'installed: {C.BIBlue}pillow{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}pillow{C.ColorOff}'

def getPSUtil():
    '''system monitoring, profiling and limiting process resources'''
    # %pip install -q psutil
    print(f'installed: {C.BIBlue}psutil{C.ColorOff}')
    # sleep(1)
    return f'installed: {C.BIBlue}psutil{C.ColorOff}'
    
print('ok')

# %%
from concurrent.futures import ThreadPoolExecutor
from concurrent.futures import wait

start = perf_counter()
with ThreadPoolExecutor(max_workers=2) as executor:

    thread_1 = executor.submit(getNumpy)
    
    thread_2 = executor.submit(getMatplotlib)
    
    thread_3 = executor.submit(getCV2)
    
    # thread_4 = executor.submit(getSciPi)
    
    # thread_5 = executor.submit(getResults)
    
    # thread_6 = executor.submit(getBeautifulSoup)
    
    # thread_7 = executor.submit(get_htmlib)
    
    # thread_8 = executor.submit(get_lxml)
    
    # thread_9 = executor.submit(getSeaborn)
    
    # thread_10 = executor.submit(getImutils)
    
    thread_11 = executor.submit(getPillow)
    
    # thread_12 = executor.submit(getPSUtil)
    
    thread_13 = executor.submit(getTFLiteModelMaker)

    thread_14 = executor.submit(getTensorflow)
    
    thread_15 = executor.submit(getTFHub)
    
    thread_16 = executor.submit(getTensorflowDatasets)
    
    thread_17 = executor.submit(getTFLiteSupport)
    
    thread_18 = executor.submit(getTFLiteRuntime)

finish = perf_counter()
print()
printTime(start,finish)

# %%
printTime(start, finish)
print(thread_1.result())
print(thread_2.result())
print(thread_3.result())
# print(thread_4.result())
# print(thread_5.result())
# print(thread_6.result())
# print(thread_7.result())
# print(thread_8.result())
# print(thread_9.result())
# print(thread_10.result())
print(thread_11.result())
# print(thread_12.result())
print(thread_13.result())
print(thread_14.result())
print(thread_15.result())
print(thread_16.result())
print(thread_17.result())
print(thread_18.result())

# %%
import tensorflow as tf
import cv2
import numpy as np

modelPath=join(contentPath, 'Defcon4_fp16.tflite')
imagePath=join(contentPath, '3b7d7d8a64.jpg')

image=cv2.imread(imagePath, cv2.IMREAD_COLOR)
image=np.expand_dims(image, axis=0)

import numpy as np
import tensorflow as tf
import cv2

def loadTFLiteModel(model_path, image_path):
    '''Load the model\npath:Path to tflite model.\npath to image.'''
    # input_data = cv2.imread(imagePath, cv2.IMREAD_COLOR)
    input_data = image
    interpreter = tf.lite.Interpreter(model_path = modelPath)
    interpreter.allocate_tensors()
    # Get input and output tensors.
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()
    # Load image data with dtype=np.uint8
    input_data = image
    # The input data's shape should match input_details[0]['shape'], which is
    # BATCH_SIZE x HEIGHT (192) x WIDTH (192) x CHANNELS (3)
    interpreter.set_tensor(input_details[0]['index'], input_data)

    interpreter.invoke()

    # The function `get_tensor()` returns a copy of the tensor data.
    # Use `tensor()` in order to get a pointer to the tensor.
    output_dict = {
        'num_detections': int(interpreter.get_tensor(outputs[3]["index"])),
        'detection_classes': interpreter.get_tensor(outputs[1]["index"]).astype(np.uint8),
        'detection_boxes' : interpreter.get_tensor(outputs[0]["index"]),
        'detection_scores' : interpreter.get_tensor(outputs[2]["index"])
        }
loadTFLiteModel(model_path=modelPath, image_path=imagePath)

# %%
help(loadTFLiteModel)

# %%
# 231 modules installed at start
import sys, psutil
alreadyInstalledList=set([each.split('.')[0] for each in sys.modules.keys()])
modul = sys.modules.keys()

for idx, item in enumerate(alreadyInstalledList):
    if item in sorted(alreadyInstalledList):
        # print(f'{idx} {C.BIBlue}{item}{C.ColorOff}')
        pass
print(f'{idx} modules installed')

# %%
from tflite_support import flatbuffers
from tflite_support import metadata as _metadata
from tflite_support import metadata_schema_py_generated as _metadata_fb

""" ... """
"""Creates the metadata for an image classifier."""

# Creates model info.
model_meta = _metadata_fb.ModelMetadataT()
model_meta.name = "MobileNetV1 image classifier"
model_meta.description = ("Identify the most prominent object in the "
                          "image from a set of 1,001 categories such as "
                          "trees, animals, food, vehicles, person etc.")
model_meta.version = "v1"
model_meta.author = "TensorFlow"
model_meta.license = ("Apache License. Version 2.0 "
                      "http://www.apache.org/licenses/LICENSE-2.0.")

# %%
model_meta.license
